# %% [markdown]
# ##### **Dataset: SBA Loans Case**.
# ##### **Author : Amy Mickle**
#
# Dataset ini merupakan dataset dari organisasi bernama **SBA(The Small Business Administration)** yang merupakann organisasi yang menaungi UMKM di Amerika Serikat. Tujuan dari organisasi ini dibentuk adalah untuk memudahkan UMKM di Amerika Serikat mendapatkan dana pinjaman dari bank.
#
# <br>Informasi pada dataset ini:
# <ul>
#   <li>Pinjaman dana dari perusahaan Real Estate and Rental and Leasing industry di California.</li>
#   <li>Terdiri dari 2012 baris data</li>
#   <li>Terdapat 35 kolom</li>
# </ul>
# <br>Fokus dari dataset ini yaitu memberikan informasi apakah perusahan dapat mengembalikan dana pinjaman sepenuhnya atau malah perusahan tersebut bangkrut dan SBA harus menanggung biaya pengembaliannya ke bank.
#
# Source:
# [Kaggle](https://www.kaggle.com/datasets/larsen0966/sba-loans-case-data-set?resource=download)
#  | [Complete Data](https://amstat.tandfonline.com/doi/full/10.1080/10691898.2018.1434342)
#
#
#  ## Tujuan Projek
#
#  Tujuan dari projek ini adalah untuk memprediksi apakah perusahaan akan mengembalikan dana pinjaman sepenuhnya atau tidak. Dengan memprediksi apakah perusahaan tersebut akan mengembalikan dana pinjaman sepenuhnya atau tidak, maka SBA dapat menentukan apakah perusahaan tersebut layak untuk mendapatkan pinjaman atau tidak. Dengan demikian, SBA dapat mengurangi risiko kebangkrutan perusahaan yang meminjam dana dari bank.
#
#
#  1. Exploratory Data Analysis, Hal ini bertujuan untuk mengetahui karakteristik dari dataset
#  2. Data Preprocessing, Hal ini bertujuan untuk mempersiapkan dataset untuk diproses oleh model
#  3. Feature Engineering, Hal ini bertujuan untuk menambahkan fitur baru yang dapat meningkatkan performa model
#  4. Feature Selection, Hal ini bertujuan untuk memilih fitur yang akan digunakan untuk membangun model
#   5. Model Building, Hal ini bertujuan untuk membangun model yang dapat memprediksi apakah perusahaan akan mengembalikan dana pinjaman sepenuhnya atau tidak dengan menggunakan logistic regression
#   6. Model Evaluation, Hal ini bertujuan untuk mengevaluasi performa model yang telah dibangun
#
#   Berikut ini uraian yang harus dilakukan pada projek ini:
#
#   1. Mempersiapkan dataset
#      - Import Library
#      - Exploratory Data Analysis
#       - Data Preprocessing
#       - Feature Engineering
#       - Feature Selection
#   2. Membangun model
#      - Logistic Regression
#
#
#   Deskripsi dataset:
#   1. Selected

# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Memuat Datasets

# %% [markdown]
# ##  Membaca Datasets

# %%
df = pd.read_csv('data/SBAcase.11.13.17.csv')

df
# Out:
#       Selected  LoanNr_ChkDgt                            Name         City  \
# 0            0     1004285007        SIMPLEX OFFICE SOLUTIONS      ANAHEIM
# 1            1     1004535010               DREAM HOME REALTY     TORRANCE
# 2            0     1005005006   Winset, Inc. dba Bankers Hill    SAN DIEGO
# 3            1     1005535001                Shiva Management    SAN DIEGO
# 4            1     1005996006      GOLD CROWN HOME LOANS, INC  LOS ANGELES
# ...        ...            ...                             ...          ...
# 2097         1     9893874006  MEGA VIDEO & WIRELESS HIGHLAND     HIGHLAND
# 2098         1     9901143004  MOVING CONNECTION & CARL'S TRA     EL CAJON
# 2099         0     9903293007       A.J. STUDIO RENTALS, INC.    CAMARILLO
# 2100         1     9925643006    TAHOE MOTION PICTURE RENTALS   SUN VALLEY
# 2101         0     9958873001                  EFM ASSOCIATES  LOS ANGELES
#
#      State    Zip                          Bank BankState   NAICS  \
# 0       CA  92801       CALIFORNIA BANK & TRUST        CA  532420
# 1       CA  90505       CALIFORNIA BANK & TRUST        CA  531210
# 2       CA  92103       CALIFORNIA BANK & TRUST        CA  531210
# 3       CA  92108       CALIFORNIA BANK & TRUST        CA  531312
# 4       CA  91345  SBA - EDF ENFORCEMENT ACTION        CO  531390
# ...    ...    ...                           ...       ...     ...
# 2097    CA  92346                    UNITI BANK        CA  532230
# 2098    CA  92021     ZIONS FIRST NATIONAL BANK        UT  532120
# 2099    CA  93012            CITY NATIONAL BANK        CA  532120
# 2100    CA  91352            CITY NATIONAL BANK        CA  532120
# 2101    CA  90068   WELLS FARGO BANK NATL ASSOC        SD  531110
#
#       ApprovalDate  ...  ChgOffPrinGr  GrAppv  SBA_Appv  New  RealEstate  \
# 0            15074  ...             0   30000     15000    0           0
# 1            15130  ...             0   30000     15000    0           0
# 2            15188  ...             0   30000     15000    0           0
# 3            15719  ...             0   50000     25000    0           0
# 4            16840  ...             0  343000    343000    0           1
# ...            ...  ...           ...     ...       ...  ...         ...
# 2097         16838  ...             0  150000     75000    1           0
# 2098         13530  ...             0   99000     79200    0           1
# 2099         13531  ...             0   50000     40000    0           0
# 2100         13542  ...             0  500000    375000    0           0
# 2101         13557  ...             0   35000     17500    0           0
#
#       Portion  Recession  daysterm       xx Default
# 0        0.50          0      1080  16175.0       0
# 1        0.50          1      1680  17658.0       0
# 2        0.50          0      1080  16298.0       0
# 3        0.50          0      1080  16816.0       0
# 4        1.00          0      7200  24103.0       0
# ...       ...        ...       ...      ...     ...
# 2097     0.50          0      1800  18691.0       0
# 2098     0.80          0      9000  22545.0       0
# 2099     0.80          0      2520  16124.0       0
# 2100     0.75          0      3600  17265.0       0
# 2101     0.50          0      1800      NaN       0
#
# [2102 rows x 35 columns]

# %% [markdown]
# <p> Menampilkan 5 data teratas </p>

# %%
df.head()
# Out:
#    Selected  LoanNr_ChkDgt                           Name         City State  \
# 0         0     1004285007       SIMPLEX OFFICE SOLUTIONS      ANAHEIM    CA
# 1         1     1004535010              DREAM HOME REALTY     TORRANCE    CA
# 2         0     1005005006  Winset, Inc. dba Bankers Hill    SAN DIEGO    CA
# 3         1     1005535001               Shiva Management    SAN DIEGO    CA
# 4         1     1005996006     GOLD CROWN HOME LOANS, INC  LOS ANGELES    CA
#
#      Zip                          Bank BankState   NAICS  ApprovalDate  ...  \
# 0  92801       CALIFORNIA BANK & TRUST        CA  532420         15074  ...
# 1  90505       CALIFORNIA BANK & TRUST        CA  531210         15130  ...
# 2  92103       CALIFORNIA BANK & TRUST        CA  531210         15188  ...
# 3  92108       CALIFORNIA BANK & TRUST        CA  531312         15719  ...
# 4  91345  SBA - EDF ENFORCEMENT ACTION        CO  531390         16840  ...
#
#    ChgOffPrinGr  GrAppv  SBA_Appv  New  RealEstate  Portion  Recession  \
# 0             0   30000     15000    0           0      0.5          0
# 1             0   30000     15000    0           0      0.5          1
# 2             0   30000     15000    0           0      0.5          0
# 3             0   50000     25000    0           0      0.5          0
# 4             0  343000    343000    0           1      1.0          0
#
#    daysterm       xx Default
# 0      1080  16175.0       0
# 1      1680  17658.0       0
# 2      1080  16298.0       0
# 3      1080  16816.0       0
# 4      7200  24103.0       0
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Melihat Informasi pada dataset
#
# <p> hal ini bertujuan untuk melihat tipe data pada setiap fitur yang ada pada datasets </p>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2102 entries, 0 to 2101
# Data columns (total 35 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Selected           2102 non-null   int64
#  1   LoanNr_ChkDgt      2102 non-null   int64
#  2   Name               2102 non-null   object
#  3   City               2102 non-null   object
#  4   State              2102 non-null   object
#  5   Zip                2102 non-null   int64
#  6   Bank               2099 non-null   object
#  7   BankState          2099 non-null   object
#  8   NAICS              2102 non-null   int64
#  9   ApprovalDate       2102 non-null   int64
#  10  ApprovalFY         2102 non-null   int64
#  11  Term               2102 non-null   int64
#  12  NoEmp              2102 non-null   int64
#  13  NewExist           2101 non-null   float64
#  14  CreateJob          2102 non-null   int64
#  15  RetainedJob        2102 non-null   int64
#  16  FranchiseCode      2102 non-null   int64
#  17  UrbanRural         2102 non-null   int64
#  18  RevLineCr          2100 non-null   object
#  19  LowDoc             2099 non-null   object
#  20  ChgOffDate         697 non-null    float64
#  21  DisbursementDate   2099 non-null   float64
#  22  DisbursementGross  2102 non-null   int64
#  23  BalanceGross       2102 non-null   int64
#  24  MIS_Status         2102 non-null   object
#  25  ChgOffPrinGr       2102 non-null   int64
#  26  GrAppv             2102 non-null   int64
#  27  SBA_Appv           2102 non-null   int64
#  28  New                2102 non-null   int64
#  29  RealEstate         2102 non-null   int64
#  30  Portion            2102 non-null   float64
#  31  Recession          2102 non-null   int64
#  32  daysterm           2102 non-null   int64
#  33  xx                 2099 non-null   float64
#  34  Default            2102 non-null   int64
# dtypes: float64(5), int64(22), object(8)
# memory usage: 574.9+ KB

# %% [markdown]
# ## Menampilkan nilai dari statistik deskriptif

# %%
df.describe()
# Out:
#           Selected  LoanNr_ChkDgt           Zip          NAICS  ApprovalDate  \
# count  2102.000000   2.102000e+03   2102.000000    2102.000000   2102.000000
# mean      0.500000   4.469172e+09  92698.612274  531630.902950  16179.587060
# std       0.500119   2.530069e+09   1878.208435     521.836986   1454.931276
# min       0.000000   1.004285e+09  65757.000000  531110.000000  10554.000000
# 25%       0.000000   2.392978e+09  91402.000000  531210.000000  15695.750000
# 50%       0.500000   3.621730e+09  92559.500000  531312.000000  16556.000000
# 75%       1.000000   6.551607e+09  94127.750000  532230.000000  17149.750000
# max       1.000000   9.958873e+09  96161.000000  533110.000000  18911.000000
#
#         ApprovalFY         Term        NoEmp     NewExist    CreateJob  ...  \
# count  2102.000000  2102.000000  2102.000000  2101.000000  2102.000000  ...
# mean   2004.035680   126.980495    10.150809     1.153736     2.549952  ...
# std       4.006321    93.798944    34.402420     0.362099     8.010175  ...
# min    1989.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%    2003.000000    60.000000     2.000000     1.000000     0.000000  ...
# 50%    2005.000000    84.000000     3.000000     1.000000     0.000000  ...
# 75%    2007.000000   240.000000     8.000000     1.000000     2.000000  ...
# max    2012.000000   306.000000   650.000000     2.000000   130.000000  ...
#
#        ChgOffPrinGr        GrAppv      SBA_Appv          New   RealEstate  \
# count  2.102000e+03  2.102000e+03  2.102000e+03  2102.000000  2102.000000
# mean   2.002908e+04  2.330641e+05  1.891759e+05     0.154139     0.274500
# std    7.543229e+04  3.436310e+05  2.989268e+05     0.361168     0.446368
# min    0.000000e+00  4.500000e+03  2.250000e+03     0.000000     0.000000
# 25%    0.000000e+00  3.000000e+04  1.500000e+04     0.000000     0.000000
# 50%    0.000000e+00  6.100000e+04  4.168000e+04     0.000000     0.000000
# 75%    1.507350e+04  3.000000e+05  2.397562e+05     0.000000     1.000000
# max    1.509550e+06  2.350000e+06  2.115000e+06     1.000000     1.000000
#
#            Portion    Recession     daysterm            xx      Default
# count  2102.000000  2102.000000  2102.000000   2099.000000  2102.000000
# mean      0.671055     0.068506  3809.414843  20076.896141     0.326356
# std       0.186519     0.252673  2813.968318   2854.510377     0.468991
# min       0.296770     0.000000     0.000000  11524.000000     0.000000
# 25%       0.500000     0.000000  1800.000000  18316.500000     0.000000
# 50%       0.500000     0.000000  2520.000000  19270.000000     0.000000
# 75%       0.850000     0.000000  7200.000000  22335.000000     1.000000
# max       1.000000     1.000000  9180.000000  27598.000000     1.000000
#
# [8 rows x 27 columns]

# %%
# Memeriksa apakah ada data yang missing
df.isnull().sum()
# Out:
# Selected                0
# LoanNr_ChkDgt           0
# Name                    0
# City                    0
# State                   0
# Zip                     0
# Bank                    3
# BankState               3
# NAICS                   0
# ApprovalDate            0
# ApprovalFY              0
# Term                    0
# NoEmp                   0
# NewExist                1
# CreateJob               0
# RetainedJob             0
# FranchiseCode           0
# UrbanRural              0
# RevLineCr               2
# LowDoc                  3
# ChgOffDate           1405
# DisbursementDate        3
# DisbursementGross       0
# BalanceGross            0
# MIS_Status              0
# ChgOffPrinGr            0
# GrAppv                  0
# SBA_Appv                0
# New                     0
# RealEstate              0
# Portion                 0
# Recession               0
# daysterm                0
# xx                      3
# Default                 0
# dtype: int64

# %% [markdown]
# Dapat dilihat bahwa diatas ada beberapa kolom yang datanya terdapat missing value, Oleh karena itu, Untuk memudahkan dalam proses analisis, maka akan dibuat suatu list untuk menampung kolom yang datanya terdapat missing value.

# %%
# Membuat list untuk menampung nama kolom yang datanya terdapat missing value
missing_values = []

# Membuat kondisi jika suatu kolom memiliki missing value maka akan ditambahkan ke dalam list
for col in df.columns:
    if df[col].isnull().sum() > 0:
        missing_values.append(col)

# Menampilkan nama kolom yang memiliki missing value
missing_values
# Out:
# ['Bank',
#  'BankState',
#  'NewExist',
#  'RevLineCr',
#  'LowDoc',
#  'ChgOffDate',
#  'DisbursementDate',
#  'xx']

# %%
# Menampilkan informasi kolom yang memiliki missing value
df[missing_values].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2102 entries, 0 to 2101
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Bank              2099 non-null   object
#  1   BankState         2099 non-null   object
#  2   NewExist          2101 non-null   float64
#  3   RevLineCr         2100 non-null   object
#  4   LowDoc            2099 non-null   object
#  5   ChgOffDate        697 non-null    float64
#  6   DisbursementDate  2099 non-null   float64
#  7   xx                2099 non-null   float64
# dtypes: float64(4), object(4)
# memory usage: 131.5+ KB

# %%
# Menghitung jumlah missing value pada kolom yang memiliki missing value
df[missing_values].isnull().sum()
# Out:
# Bank                   3
# BankState              3
# NewExist               1
# RevLineCr              2
# LowDoc                 3
# ChgOffDate          1405
# DisbursementDate       3
# xx                     3
# dtype: int64

# %%
# Membuat list untuk menampung nama kolom yang datanya terdapat missing value dan tipe datanya adalah object
missing_values_object = []

# Membuat list untuk menampung nama kolom yang datanya terdapat missing value dan tipe datanya adalah float
missing_values_float = []

# Membuat kondisi jika suatu kolom memiliki missing value dan tipe datanya adalah object maka akan ditambahkan ke dalam list
for col in df.columns:
    if df[col].isnull().sum() > 0 and df[col].dtype == 'object':
        missing_values_object.append(col)

# Membuat kondisi jika suatu kolom memiliki missing value dan tipe datanya adalah float maka akan ditambahkan ke dalam list
for col in df.columns:
    if df[col].isnull().sum() > 0 and df[col].dtype == 'float64':
        missing_values_float.append(col)

# Menampilkan nama kolom yang memiliki missing value dan tipe datanya adalah object
print(missing_values_object)

# Menampilkan nama kolom yang memiliki missing value dan tipe datanya adalah float
print(missing_values_float)
# Out:
# ['Bank', 'BankState', 'RevLineCr', 'LowDoc']
# ['NewExist', 'ChgOffDate', 'DisbursementDate', 'xx']

# %%
# Melihat jumlah missing value pada kolom yang memiliki missing value dan tipe datanya adalah object
df[missing_values_object].isnull().sum()
# Out:
# Bank         3
# BankState    3
# RevLineCr    2
# LowDoc       3
# dtype: int64

# %% [markdown]
# # Feature Engineering
#
# dapat dilihat bahwa kolom yang bertipe data object hanya memiliki sedikit missing value, oleh karena itu, missing value pada kolom tersebut akan dihapus saja karena data yang sedikit tidak akan terlalu mempengaruhi hasil analisis.

# %%
# Menghapus missing value pada kolom yang memiliki missing value dan tipe datanya adalah object
df.dropna(subset=missing_values_object, inplace=True)

# %%
df
# Out:
#       Selected  LoanNr_ChkDgt                            Name         City  \
# 0            0     1004285007        SIMPLEX OFFICE SOLUTIONS      ANAHEIM
# 1            1     1004535010               DREAM HOME REALTY     TORRANCE
# 2            0     1005005006   Winset, Inc. dba Bankers Hill    SAN DIEGO
# 3            1     1005535001                Shiva Management    SAN DIEGO
# 4            1     1005996006      GOLD CROWN HOME LOANS, INC  LOS ANGELES
# ...        ...            ...                             ...          ...
# 2097         1     9893874006  MEGA VIDEO & WIRELESS HIGHLAND     HIGHLAND
# 2098         1     9901143004  MOVING CONNECTION & CARL'S TRA     EL CAJON
# 2099         0     9903293007       A.J. STUDIO RENTALS, INC.    CAMARILLO
# 2100         1     9925643006    TAHOE MOTION PICTURE RENTALS   SUN VALLEY
# 2101         0     9958873001                  EFM ASSOCIATES  LOS ANGELES
#
#      State    Zip                          Bank BankState   NAICS  \
# 0       CA  92801       CALIFORNIA BANK & TRUST        CA  532420
# 1       CA  90505       CALIFORNIA BANK & TRUST        CA  531210
# 2       CA  92103       CALIFORNIA BANK & TRUST        CA  531210
# 3       CA  92108       CALIFORNIA BANK & TRUST        CA  531312
# 4       CA  91345  SBA - EDF ENFORCEMENT ACTION        CO  531390
# ...    ...    ...                           ...       ...     ...
# 2097    CA  92346                    UNITI BANK        CA  532230
# 2098    CA  92021     ZIONS FIRST NATIONAL BANK        UT  532120
# 2099    CA  93012            CITY NATIONAL BANK        CA  532120
# 2100    CA  91352            CITY NATIONAL BANK        CA  532120
# 2101    CA  90068   WELLS FARGO BANK NATL ASSOC        SD  531110
#
#       ApprovalDate  ...  ChgOffPrinGr  GrAppv  SBA_Appv  New  RealEstate  \
# 0            15074  ...             0   30000     15000    0           0
# 1            15130  ...             0   30000     15000    0           0
# 2            15188  ...             0   30000     15000    0           0
# 3            15719  ...             0   50000     25000    0           0
# 4            16840  ...             0  343000    343000    0           1
# ...            ...  ...           ...     ...       ...  ...         ...
# 2097         16838  ...             0  150000     75000    1           0
# 2098         13530  ...             0   99000     79200    0           1
# 2099         13531  ...             0   50000     40000    0           0
# 2100         13542  ...             0  500000    375000    0           0
# 2101         13557  ...             0   35000     17500    0           0
#
#       Portion  Recession  daysterm       xx Default
# 0        0.50          0      1080  16175.0       0
# 1        0.50          1      1680  17658.0       0
# 2        0.50          0      1080  16298.0       0
# 3        0.50          0      1080  16816.0       0
# 4        1.00          0      7200  24103.0       0
# ...       ...        ...       ...      ...     ...
# 2097     0.50          0      1800  18691.0       0
# 2098     0.80          0      9000  22545.0       0
# 2099     0.80          0      2520  16124.0       0
# 2100     0.75          0      3600  17265.0       0
# 2101     0.50          0      1800      NaN       0
#
# [2094 rows x 35 columns]

# %%
# Melihat jumlah missing value pada kolom yang memiliki missing value dan tipe datanya adalah float64
df[missing_values_float].isnull().sum()
# Out:
# NewExist               1
# ChgOffDate          1399
# DisbursementDate       3
# xx                     3
# dtype: int64

# %% [markdown]
# Diatas dapat dilihat bahwa kolom yang bertipe float64 memiliki banyak missing value, oleh karena itu, missing value pada kolom tersebut akan diisi dengan nilai mean dari kolom tersebut.

# %%
# Karena jumlah missing value pada kolom yang memiliki missing value dan tipe datanya adalah float64 sangat banyak, maka kita akan menggunakan teknik mean untuk mengisi missing value tersebut
for col in missing_values_float:
    df[col].fillna(df[col].mean(), inplace=True)

df
# Out:
#       Selected  LoanNr_ChkDgt                            Name         City  \
# 0            0     1004285007        SIMPLEX OFFICE SOLUTIONS      ANAHEIM
# 1            1     1004535010               DREAM HOME REALTY     TORRANCE
# 2            0     1005005006   Winset, Inc. dba Bankers Hill    SAN DIEGO
# 3            1     1005535001                Shiva Management    SAN DIEGO
# 4            1     1005996006      GOLD CROWN HOME LOANS, INC  LOS ANGELES
# ...        ...            ...                             ...          ...
# 2097         1     9893874006  MEGA VIDEO & WIRELESS HIGHLAND     HIGHLAND
# 2098         1     9901143004  MOVING CONNECTION & CARL'S TRA     EL CAJON
# 2099         0     9903293007       A.J. STUDIO RENTALS, INC.    CAMARILLO
# 2100         1     9925643006    TAHOE MOTION PICTURE RENTALS   SUN VALLEY
# 2101         0     9958873001                  EFM ASSOCIATES  LOS ANGELES
#
#      State    Zip                          Bank BankState   NAICS  \
# 0       CA  92801       CALIFORNIA BANK & TRUST        CA  532420
# 1       CA  90505       CALIFORNIA BANK & TRUST        CA  531210
# 2       CA  92103       CALIFORNIA BANK & TRUST        CA  531210
# 3       CA  92108       CALIFORNIA BANK & TRUST        CA  531312
# 4       CA  91345  SBA - EDF ENFORCEMENT ACTION        CO  531390
# ...    ...    ...                           ...       ...     ...
# 2097    CA  92346                    UNITI BANK        CA  532230
# 2098    CA  92021     ZIONS FIRST NATIONAL BANK        UT  532120
# 2099    CA  93012            CITY NATIONAL BANK        CA  532120
# 2100    CA  91352            CITY NATIONAL BANK        CA  532120
# 2101    CA  90068   WELLS FARGO BANK NATL ASSOC        SD  531110
#
#       ApprovalDate  ...  ChgOffPrinGr  GrAppv  SBA_Appv  New  RealEstate  \
# 0            15074  ...             0   30000     15000    0           0
# 1            15130  ...             0   30000     15000    0           0
# 2            15188  ...             0   30000     15000    0           0
# 3            15719  ...             0   50000     25000    0           0
# 4            16840  ...             0  343000    343000    0           1
# ...            ...  ...           ...     ...       ...  ...         ...
# 2097         16838  ...             0  150000     75000    1           0
# 2098         13530  ...             0   99000     79200    0           1
# 2099         13531  ...             0   50000     40000    0           0
# 2100         13542  ...             0  500000    375000    0           0
# 2101         13557  ...             0   35000     17500    0           0
#
#       Portion  Recession  daysterm            xx Default
# 0        0.50          0      1080  16175.000000       0
# 1        0.50          1      1680  17658.000000       0
# 2        0.50          0      1080  16298.000000       0
# 3        0.50          0      1080  16816.000000       0
# 4        1.00          0      7200  24103.000000       0
# ...       ...        ...       ...           ...     ...
# 2097     0.50          0      1800  18691.000000       0
# 2098     0.80          0      9000  22545.000000       0
# 2099     0.80          0      2520  16124.000000       0
# 2100     0.75          0      3600  17265.000000       0
# 2101     0.50          0      1800  20085.048302       0
#
# [2094 rows x 35 columns]

# %%
# Terakhir mengecek apakah masih ada missing value
df.isnull().sum()
# Out:
# Selected             0
# LoanNr_ChkDgt        0
# Name                 0
# City                 0
# State                0
# Zip                  0
# Bank                 0
# BankState            0
# NAICS                0
# ApprovalDate         0
# ApprovalFY           0
# Term                 0
# NoEmp                0
# NewExist             0
# CreateJob            0
# RetainedJob          0
# FranchiseCode        0
# UrbanRural           0
# RevLineCr            0
# LowDoc               0
# ChgOffDate           0
# DisbursementDate     0
# DisbursementGross    0
# BalanceGross         0
# MIS_Status           0
# ChgOffPrinGr         0
# GrAppv               0
# SBA_Appv             0
# New                  0
# RealEstate           0
# Portion              0
# Recession            0
# daysterm             0
# xx                   0
# Default              0
# dtype: int64

# %% [markdown]
# Menampilkan semua kolom yang ada pada dataset

# %%
# list all columns
df.columns
# Out:
# Index(['Selected', 'LoanNr_ChkDgt', 'Name', 'City', 'State', 'Zip', 'Bank',
#        'BankState', 'NAICS', 'ApprovalDate', 'ApprovalFY', 'Term', 'NoEmp',
#        'NewExist', 'CreateJob', 'RetainedJob', 'FranchiseCode', 'UrbanRural',
#        'RevLineCr', 'LowDoc', 'ChgOffDate', 'DisbursementDate',
#        'DisbursementGross', 'BalanceGross', 'MIS_Status', 'ChgOffPrinGr',
#        'GrAppv', 'SBA_Appv', 'New', 'RealEstate', 'Portion', 'Recession',
#        'daysterm', 'xx', 'Default'],
#       dtype='object')

# %% [markdown]
# ## Menghapus kolom yang tidak diperlukan

# %%
# Menghapus kolom yang tidak diperlukan

df = df.drop(['Selected', 'Name', 'City', 'State', 'Bank', 'BankState', 'ApprovalDate', 'ApprovalFY', 'ChgOffDate', 'DisbursementDate',  ], axis=1)

# %% [markdown]
# ## Melakukan label encoding pada kolom RevLineCr, LowDOc, MIS_Status

# %%
from sklearn import preprocessing

def label_encoder(y):
    le = preprocessing.LabelEncoder()
    le.fit(y)
    return le.transform(y)

list_variabel_encoder = ['RevLineCr', 'LowDoc', 'MIS_Status']

for i in list_variabel_encoder:
    df[i] = label_encoder(df[i])

df
# Out:
#       LoanNr_ChkDgt    Zip   NAICS  Term  NoEmp  NewExist  CreateJob  \
# 0        1004285007  92801  532420    36      1       1.0          0
# 1        1004535010  90505  531210    56      1       1.0          0
# 2        1005005006  92103  531210    36     10       1.0          0
# 3        1005535001  92108  531312    36      6       1.0          0
# 4        1005996006  91345  531390   240     65       1.0          3
# ...             ...    ...     ...   ...    ...       ...        ...
# 2097     9893874006  92346  532230    60      5       2.0          0
# 2098     9901143004  92021  532120   300      4       1.0          0
# 2099     9903293007  93012  532120    84      2       1.0          0
# 2100     9925643006  91352  532120   120      3       1.0          0
# 2101     9958873001  90068  531110    60      4       1.0          0
#
#       RetainedJob  FranchiseCode  UrbanRural  ...  ChgOffPrinGr  GrAppv  \
# 0               0              1           0  ...             0   30000
# 1               0              1           0  ...             0   30000
# 2               0              1           0  ...             0   30000
# 3               0              1           0  ...             0   50000
# 4              65              1           1  ...             0  343000
# ...           ...            ...         ...  ...           ...     ...
# 2097            5              1           1  ...             0  150000
# 2098            0              1           0  ...             0   99000
# 2099            0              1           0  ...             0   50000
# 2100            0              1           0  ...             0  500000
# 2101            0              1           0  ...             0   35000
#
#       SBA_Appv  New  RealEstate  Portion  Recession  daysterm            xx  \
# 0        15000    0           0     0.50          0      1080  16175.000000
# 1        15000    0           0     0.50          1      1680  17658.000000
# 2        15000    0           0     0.50          0      1080  16298.000000
# 3        25000    0           0     0.50          0      1080  16816.000000
# 4       343000    0           1     1.00          0      7200  24103.000000
# ...        ...  ...         ...      ...        ...       ...           ...
# 2097     75000    1           0     0.50          0      1800  18691.000000
# 2098     79200    0           1     0.80          0      9000  22545.000000
# 2099     40000    0           0     0.80          0      2520  16124.000000
# 2100    375000    0           0     0.75          0      3600  17265.000000
# 2101     17500    0           0     0.50          0      1800  20085.048302
#
#       Default
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 2097        0
# 2098        0
# 2099        0
# 2100        0
# 2101        0
#
# [2094 rows x 25 columns]

# %% [markdown]
# # Memisahkan antara fitur dan target

# %%
# Split data training dan data testing
from sklearn.model_selection import train_test_split

X = df.drop('Default', axis=1) # Features
y = df['Default'] # Labels

# %% [markdown]
# # Membagi dataset menjadi train dan test

# %%
# membagi data menjadi data training dan data testing
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# memanggil model
from sklearn.linear_model import LogisticRegression

# membuat objek model
model = LogisticRegression(random_state = 16, solver='liblinear' )

# training model
model.fit(X_train, y_train)

# mengevaluasi model
model.score(X_test, y_test)

# membuat prediksi

y_pred = model.predict(X_test)

# %% [markdown]
# # Menampilkan confusion matrix dan classification report

# %%
# Menampilkan confustion matrix
import matplotlib.pyplot as plt
from sklearn.metrics._plot.confusion_matrix import confusion_matrix
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_, )

disp.plot()
plt.show()

# %%
# Menampilkan classification report
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      1.00      0.79       413
#            1       0.00      0.00      0.00       216
#
#     accuracy                           0.66       629
#    macro avg       0.33      0.50      0.40       629
# weighted avg       0.43      0.66      0.52       629
# /home/abdulhafidh/Documents/Semester 6 (23 SKS)/Machine Learning (3 SKS)/project/env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/abdulhafidh/Documents/Semester 6 (23 SKS)/Machine Learning (3 SKS)/project/env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/abdulhafidh/Documents/Semester 6 (23 SKS)/Machine Learning (3 SKS)/project/env/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # ROC CURVE

# %%
# Menampilkan ROC AUC
from sklearn.metrics import roc_auc_score

pred_auc = model.predict_proba(X_test)[:,1]
acc = roc_auc_score(y_test, pred_auc)
print('ROC AUC: %.3f' % acc)
# Out:
# ROC AUC: 0.773

# %%
# Visualisasi ROC AUC
from sklearn.metrics import plot_roc_curve, auc, roc_curve

prob_estimates = model.predict_proba(X_test)
fpr, tpr, thresholds = roc_curve(y_test, prob_estimates[:, 1])
roc_auc = auc(fpr, tpr)

plt.plot(fpr,tpr,'b', label=f'AUC={roc_auc}')
plt.plot([0,1],[0,1],'r--', label='Random Classifier')

plt.title('ROC Curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # Menghitung MSE (Mean Square Error) dan RMSE (Root Mean Square Error)

# %%
# Menghitung MSE
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(y_test, y_pred)


mse
# Out:
# 0.34340222575516693

# %%
# Menghitung error dengan menggunakan RMSE
rmse = np.sqrt(mse)

rmse
# Out:
# 0.5860053120537108

# %%
#

# %% [markdown]
# # Menampilkan Hasil ke dalam bentuk dataframe

# %%
# show the result in table
result = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})

# reset index
result = result.reset_index(drop=True)

# Menyimpan hasil prediksi ke dalam file csv
result.to_csv('data/result_loanDefaultPrediction.csv', index=False)

result
# Out:
#      Actual  Predicted
# 0         1          0
# 1         0          0
# 2         0          0
# 3         1          0
# 4         0          0
# ..      ...        ...
# 624       0          0
# 625       1          0
# 626       0          0
# 627       1          0
# 628       0          0
#
# [629 rows x 2 columns]
